# %% [markdown]
# Hello, My name is Bryan Lee Santoso. Welcome to my data analytics project about marathon runners. Thank you to Ryan & Matt Data Science for the tutorial on this project. Here, I am analyzing the data of marathons in Hong Kong in the 50km/50mi running category in 2022. STILL WORK IN PROGRESS
#
# Dataset Kaggle source -> https://www.kaggle.com/datasets/aiaiaidavid/the-big-dataset-of-ultra-marathon-running?resource=download&select=TWO_CENTURIES_OF_UM_RACES.csv

# %%
# Importing all necessary libraries
import pandas as pd
import seaborn as sns

# %%
# Importing the dataset
# The dataset is assumed to be in the same directory as this script
df = pd.read_csv("TWO_CENTURIES_OF_UM_RACES.csv")
# Out:
# C:\Users\Bryan Lee\AppData\Local\Temp\ipykernel_21412\3690217006.py:3: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("TWO_CENTURIES_OF_UM_RACES.csv")
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21412\3690217006.py in ?()
#       1 # Importing the dataset
#       2 # The dataset is assumed to be in the same directory as this script
# ----> 3 df = pd.read_csv("TWO_CENTURIES_OF_UM_RACES.csv")
#
# ...

# %%
# Showing the first 10 rows of the dataset
# This will help us understand the structure of the dataset
df.head(10)
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
# 5           2018  06.01.2018  Selva Costera (CHI)                  50km
# 6           2018  06.01.2018  Selva Costera (CHI)                  50km
# 7           2018  06.01.2018  Selva Costera (CHI)                  50km
# 8           2018  06.01.2018  Selva Costera (CHI)                  50km
# 9           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance         Athlete club  \
# 0                         22           4:51:39 h                Tnfrc
# ...

# %%
df.shape
# Out:
# (7461195, 13)

# %%
df.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# dtype: object

# %%
# Time to clean up the dataset
# Say we only want USA Races, 50K OR 50mI, 2020

# %%
#Show 50k
df[df["Event distance/length"] == '50km']
# Out:
#          Year of event Event dates                             Event name  \
# 0                 2018  06.01.2018                    Selva Costera (CHI)
# 1                 2018  06.01.2018                    Selva Costera (CHI)
# 2                 2018  06.01.2018                    Selva Costera (CHI)
# 3                 2018  06.01.2018                    Selva Costera (CHI)
# 4                 2018  06.01.2018                    Selva Costera (CHI)
# ...                ...         ...                                    ...
# 7461089           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461090           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461091           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461092           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461093           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
# Combine 50k and 50mI with isin
df[df["Event distance/length"].isin(['50km', '50mi'])]
# Out:
#          Year of event Event dates                        Event name  \
# 0                 2018  06.01.2018               Selva Costera (CHI)
# 1                 2018  06.01.2018               Selva Costera (CHI)
# 2                 2018  06.01.2018               Selva Costera (CHI)
# 3                 2018  06.01.2018               Selva Costera (CHI)
# 4                 2018  06.01.2018               Selva Costera (CHI)
# ...                ...         ...                               ...
# 7461181           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461182           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461183           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461184           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461185           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
#Now we only want to see the ones in 2020
df[df["Event distance/length"].isin(['50km', '50mi']) & (df["Year of event"] == 2022)]
# Out:
#          Year of event Event dates                             Event name  \
# 3138208           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138209           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138210           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138211           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138212           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# ...                ...         ...                                    ...
# 3609801           2022  16.10.2022     Tussey Mountainback 50 Miler (USA)
# 3609802           2022  16.10.2022     Tussey Mountainback 50 Miler (USA)
# 3609803           2022  16.10.2022     Tussey Mountainback 50 Miler (USA)
# 3609804           2022  16.10.2022     Tussey Mountainback 50 Miler (USA)
# 3609805           2022  16.10.2022     Tussey Mountainback 50 Miler (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
df[df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'HKG']
# Out:
#          Year of event        Event dates  \
# 445               2018         01.01.2018
# 446               2018         01.01.2018
# 447               2018         01.01.2018
# 448               2018         01.01.2018
# 449               2018         01.01.2018
# ...                ...                ...
# 7140034           1987         12.04.1987
# 7217303           1989  31.01.-01.02.1989
# 7217304           1989  31.01.-01.02.1989
# 7299607           1991     09.-10.02.1991
# 7378891           1993     20.-21.02.1993
#
#                                                 Event name  \
# 445                            The First Walk - 50km (HKG)
# 446                            The First Walk - 50km (HKG)
# 447                            The First Walk - 50km (HKG)
# 448                            The First Walk - 50km (HKG)
# 449                            The First Walk - 50km (HKG)
# ...                                                    ...
# ...

# %%
# Now we want to combine all the filters together
df[df["Event distance/length"].isin(['50km', '50mi']) & (df["Year of event"] == 2022) & (df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'HKG') ]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[67], line 2
#       1 # Now we want to combine all the filters together
# ----> 2 df[df["Event distance/length"].isin(['50km', '50mi']) & (df["Year of event"] == 2022) & (df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'HKG') ]
#
# File d:\uni\2ND YEAR SEM B\PROJECTS\data-analytics-marathon-project\.venv\Lib\site-packages\pandas\core\strings\accessor.py:1131, in StringMethods.get(self, i)
#    1071 def get(self, i):
#    1072     """
#    1073     Extract element from each component at specified position or with specified key.
#    1074
#    (...)   1129     dtype: object
#    1130     """
# -> 1131     result = self._data.array._str_get(i)
#    1132     return self._wrap_result(result)
#
# ...

# %%
df2 = df[df["Event distance/length"].isin(['50km', '50mi']) & (df["Year of event"] == 2022) & (df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'HKG') ]
df2
# Out:
# (447, 13)

# %%
# Want to remove the 'HKG' from the event name
df2'].str.split('(').str.get(0)

# %%
df2
# Out:
#          Year of event Event dates       Event name Event distance/length  \
# 3545714           2022  10.12.2022  MSIG Lantau 50                   50km
# 3545715           2022  10.12.2022  MSIG Lantau 50                   50km
# 3545716           2022  10.12.2022  MSIG Lantau 50                   50km
# 3545717           2022  10.12.2022  MSIG Lantau 50                   50km
# 3545718           2022  10.12.2022  MSIG Lantau 50                   50km
# 3545719           2022  10.12.2022  MSIG Lantau 50                   50km
# 3545720           2022  10.12.2022  MSIG Lantau 50                   50km
# 3545721           2022  10.12.2022  MSIG Lantau 50                   50km
# 3545722           2022  10.12.2022  MSIG Lantau 50                   50km
# 3545723           2022  10.12.2022  MSIG Lantau 50                   50km
#
#          Event number of finishers Athlete performance Athlete gender  \
# 3545714                        125             6:58:49              M
# ...

# %%
# Cleaning up the athlete data
df2ered['Athdf2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\uni\2ND YEAR SEM B\PROJECTS\data-analytics-marathon-project\.venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Athlete year of birth'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[87], line 2
# ...

# %%
# remove the h from Athlete performance
df2['Athlete performance'] = df2['Athlete performance'].str.split(' ').str.get(0)
# Out:
# C:\Users\Bryan Lee\AppData\Local\Temp\ipykernel_21412\3439131914.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['Athlete performance'] = df_filtered['Athlete performance'].str.split(' ').str.get(0)

# %%
df2.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 df2.head(10)
#
# NameError: name 'df2' is not defined

# %%
df2.head(10)
# Out:
#          Year of event Event dates       Event name Event distance/length  \
# 3545714           2022  10.12.2022  MSIG Lantau 50                   50km
# 3545715           2022  10.12.2022  MSIG Lantau 50                   50km
# 3545716           2022  10.12.2022  MSIG Lantau 50                   50km
# 3545717           2022  10.12.2022  MSIG Lantau 50                   50km
# 3545718           2022  10.12.2022  MSIG Lantau 50                   50km
# 3545719           2022  10.12.2022  MSIG Lantau 50                   50km
# 3545720           2022  10.12.2022  MSIG Lantau 50                   50km
# 3545721           2022  10.12.2022  MSIG Lantau 50                   50km
# 3545722           2022  10.12.2022  MSIG Lantau 50                   50km
# 3545723           2022  10.12.2022  MSIG Lantau 50                   50km
#
#          Event number of finishers Athlete performance Athlete gender  \
# 3545714                        125             6:58:49              M
# ...

# %%
# Time to clean up null values
df2.isnull().sum()
# Out:
# Year of event                 0
# Event dates                   0
# Event name                    0
# Event distance/length         0
# Event number of finishers     0
# Athlete performance           0
# Athlete gender                0
# Athlete average speed         0
# Athlete ID                    0
# athlete_age                  44
# dtype: int64

# %%
df2[df2['athlete_age'].isnull()]
# Out:
#          Year of event Event dates       Event name Event distance/length  \
# 3545722           2022  10.12.2022  MSIG Lantau 50                   50km
# 3545725           2022  10.12.2022  MSIG Lantau 50                   50km
# 3545727           2022  10.12.2022  MSIG Lantau 50                   50km
# 3545732           2022  10.12.2022  MSIG Lantau 50                   50km
# 3545737           2022  10.12.2022  MSIG Lantau 50                   50km
# 3545738           2022  10.12.2022  MSIG Lantau 50                   50km
# 3545739           2022  10.12.2022  MSIG Lantau 50                   50km
# 3545744           2022  10.12.2022  MSIG Lantau 50                   50km
# 3545746           2022  10.12.2022  MSIG Lantau 50                   50km
# 3545750           2022  10.12.2022  MSIG Lantau 50                   50km
# 3545752           2022  10.12.2022  MSIG Lantau 50                   50km
# 3545753           2022  10.12.2022  MSIG Lantau 50                   50km
# ...

# %%
df2 = df2.dropna(subset=['athlete_age'])
df2.isnull().sum()
df2.shape
# Out:
# (403, 10)

# %%
#Check for duplicates values
df2[df2.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete gender, Athlete average speed, Athlete ID, athlete_age]
# Index: []

# %%
# Reset index
df2.reset_index(drop=True)
# Out:
#      Year of event Event dates                     Event name  \
# 0             2022  10.12.2022                MSIG Lantau 50
# 1             2022  10.12.2022                MSIG Lantau 50
# 2             2022  10.12.2022                MSIG Lantau 50
# 3             2022  10.12.2022                MSIG Lantau 50
# 4             2022  10.12.2022                MSIG Lantau 50
# ..             ...         ...                            ...
# 398           2022  22.10.2022  MSIG HK50 - Hong Kong Island
# 399           2022  22.10.2022  MSIG HK50 - Hong Kong Island
# 400           2022  22.10.2022  MSIG HK50 - Hong Kong Island
# 401           2022  22.10.2022  MSIG HK50 - Hong Kong Island
# 402           2022  22.10.2022  MSIG HK50 - Hong Kong Island
#
#     Event distance/length  Event number of finishers Athlete performance  \
# 0                    50km                        125             6:58:49
# 1                    50km                        125             7:01:48
# ...

# %%
# Fixing the types
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[101], line 2
#       1 # Fixing the types
# ----> 2 df2.dtypes
#
# NameError: name 'df2' is not defined
